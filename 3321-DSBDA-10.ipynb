# %%
#Scan the dataset and give the inference as: 1. List down the features and their types (eg, numeric, nominal) available in the 
#dataset.
#2. Create a histogram for each feature in the dataset to illustrate the feature distributions 
#3. Create a boxplot for each feature in the dataset. 4. Compare distributions and identify outliers.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Import the Iris dataset
df = pd.read_csv('Iris-2.csv')

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0      1            5.1           3.5            1.4           0.2  \
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
# Preprocessing: Drop any rows with missing values
df.dropna(inplace=True)

# %%
# Data formatting
df['Species'] = df['Species'].astype('category')

# Convert all numeric columns to float data type
numeric_cols = ['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']
df[numeric_cols] = df[numeric_cols].astype(float)

# Print out the column names and data types
print("Features and their types:")
print(df.dtypes)
# Out:
# Features and their types:
# Id                  int64
# SepalLengthCm     float64
# SepalWidthCm      float64
# PetalLengthCm     float64
# PetalWidthCm      float64
# Species          category
# dtype: object

# %%
# Creating a histogram for each feature
df.hist(bins=10, figsize=(10,8))
plt.show()

# %%
# Creating a boxplot for each feature
fig, axs = plt.subplots(ncols=4, figsize=(15,6))
axs[0].boxplot(df['SepalLengthCm'])
axs[0].set_title('Sepal Length')
axs[1].boxplot(df['SepalWidthCm'])
axs[1].set_title('Sepal Width')
axs[2].boxplot(df['PetalLengthCm'])
axs[2].set_title('Petal Length')
axs[3].boxplot(df['PetalLengthCm'])
axs[3].set_title('Petal Width')
plt.show()

# %%
sns.boxplot(data=df,x='SepalLengthCm')
# Out:
# <Axes: xlabel='SepalLengthCm'>

# %%
sns.boxplot(data=df)
plt.show()

# %%
df.hist()
plt.show()

# %%
sns.kdeplot(data=df)
plt.show()

# %%
df['Species'] = df['Species'].replace({'Iris-setosa':1,'Iris-verginica':2,'Iris-versicolor':3})
from scipy import stats

z_scores = stats.zscore(df)
outliers = df[(z_scores > 3).any(axis=1)]

print("Outliers:")
print(outliers)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 4
#       1 df['Species'] = df['Species'].replace({'Iris-setosa':1,'Iris-verginica':2,'Iris-versicolor':3})
#       2 from scipy import stats
# ----> 4 z_scores = stats.zscore(df)
#       5 outliers = df[(z_scores > 3).any(axis=1)]
#       7 print("Outliers:")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\stats\_stats_py.py:2713, in zscore(a, axis, ddof, nan_policy)
#    2644 def zscore(a, axis=0, ddof=0, nan_policy='propagate'):
#    2645     """
#    2646     Compute the z score.
#    2647
#    (...)
#    2711            [-0.91611681, -0.89090508,  1.4983032 ,  0.88731639, -0.5785977 ]])
#    2712     """
# -> 2713     return zmap(a, a, axis=axis, ddof=ddof, nan_policy=nan_policy)
#
# ...
